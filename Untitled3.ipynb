# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
clean_img = '/content/drive/MyDrive/Clean_image_gray'

# %%
import os
i = os.listdir(clean_img)
len(i)
# Out:
# 51

# %%
import numpy as np
import os
import tensorflow as tf
from tqdm.notebook import tqdm
import matplotlib.pyplot as plt

# %%
clean_frames = []
for file in tqdm(sorted(os.listdir(clean_img))):
  if any(extension in file for extension in ['.jpg', 'jpeg', '.png']):
    image = tf.keras.preprocessing.image.load_img(clean_img + '/' + file, target_size= (100,100))
    image = tf.keras.preprocessing.image.img_to_array(image).astype('float32') / 255
    clean_frames.append(image)

clean_frames = np.array(clean_frames)
# Out:
#   0%|          | 0/51 [00:00<?, ?it/s]

# %%
print(clean_frames.shape)
# Out:
# (51, 100, 100, 3)

# %%
bad_frames = '/content/drive/MyDrive/Noisy_image_gray'

# %%
noisy_frames = []

for file in tqdm(sorted(os.listdir(bad_frames))):
  if any(extension in file for extension in ['.jpg', 'jpeg', '.png']):
    img = tf.keras.preprocessing.image.load_img(bad_frames + '/' + file, target_size=(100,100))
    image = tf.keras.preprocessing.image.img_to_array(img).astype('float32') / 255
    noisy_frames.append(image)
    image = np.uint8(image)

noisy_frames = np.array(noisy_frames)
# Out:
#   0%|          | 0/51 [00:00<?, ?it/s]

# %%
print(noisy_frames.shape)
# Out:
# (51, 100, 100, 3)

# %%
noisy_train = noisy_frames[0:round(len(noisy_frames)*0.8)]
noisy_test = noisy_frames[round(len(noisy_frames)*0.8):]

clean_train = clean_frames[0:round(len(clean_frames)*0.8)]
clean_test = clean_frames[round(len(clean_frames)*0.8):]

# %%
print(noisy_test.shape)
# Out:
# (10, 100, 100, 3)

# %%
import keras
from keras.models import load_model
from keras.layers import Input, Dense, Conv2D, MaxPooling2D, UpSampling2D, BatchNormalization, Activation
from keras.models import Model
from keras.callbacks import EarlyStopping, ModelCheckpoint
import os
import pickle
import numpy as np
from tensorflow.keras.optimizers import Adam

# %%
input = Input(shape=(100,100,3))
x = Conv2D(64, (3, 3), padding='same')(input)
x = Activation('relu')(x)

for i in range(15):
    x = Conv2D(64, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

x = Conv2D(3, (3, 3), padding='same')(x)
output = Activation('tanh')(x)

# %%
model = Model(input, output)

model.compile(optimizer=Adam(learning_rate=0.0009),loss='mean_squared_error',metrics=["acc"])

# %%
callbacks_lst = [
    tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', min_lr=0.0000009, min_delta=0.0001, factor=0.70, patience=3, verbose=1, mode='min'),
    tf.keras.callbacks.EarlyStopping(monitor='val_loss', mode='min', verbose=1, min_delta=0.0001, patience=15)
]

# %%
history = model.fit(noisy_train, clean_train,
                    batch_size=1,
                    epochs=100,
                    verbose=1,
                    validation_data=(noisy_test, clean_test),
                    callbacks=callbacks_lst,
                    shuffle=True)
# Out:
# Epoch 1/100
# 41/41 [==============================] - 41s 960ms/step - loss: 0.0218 - acc: 0.3690 - val_loss: 0.3726 - val_acc: 0.0976
# Epoch 2/100
# 41/41 [==============================] - 39s 952ms/step - loss: 0.0144 - acc: 0.3679 - val_loss: 0.1024 - val_acc: 0.1279
# Epoch 3/100
# 41/41 [==============================] - 39s 951ms/step - loss: 0.0135 - acc: 0.3514 - val_loss: 0.0206 - val_acc: 0.2694
# Epoch 4/100
# 41/41 [==============================] - 39s 952ms/step - loss: 0.0134 - acc: 0.3394 - val_loss: 0.0277 - val_acc: 0.1480
# Epoch 5/100
# 41/41 [==============================] - 39s 954ms/step - loss: 0.0121 - acc: 0.3703 - val_loss: 0.0762 - val_acc: 0.1975
# Epoch 6/100
# 41/41 [==============================] - 39s 946ms/step - loss: 0.0118 - acc: 0.3455 - val_loss: 0.0281 - val_acc: 0.2443
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 0.00021608999522868542.
# Epoch 28/100
# 41/41 [==============================] - 38s 940ms/step - loss: 0.0060 - acc: 0.3267 - val_loss: 0.0092 - val_acc: 0.2983
# Epoch 29/100
# 41/41 [==============================] - 38s 940ms/step - loss: 0.0059 - acc: 0.3261 - val_loss: 0.0088 - val_acc: 0.2844
# Epoch 30/100
# 41/41 [==============================] - 38s 938ms/step - loss: 0.0057 - acc: 0.3258 - val_loss: 0.0088 - val_acc: 0.2881
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 0.00015126299258554353.
# Epoch 31/100
# 41/41 [==============================] - 39s 941ms/step - loss: 0.0056 - acc: 0.3292 - val_loss: 0.0091 - val_acc: 0.2750
# Epoch 32/100
# 41/41 [==============================] - 38s 940ms/step - loss: 0.0056 - acc: 0.3319 - val_loss: 0.0089 - val_acc: 0.2511
# Epoch 33/100
# 41/41 [==============================] - 38s 939ms/step - loss: 0.0055 - acc: 0.3227 - val_loss: 0.0089 - val_acc: 0.3327
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 0.00010588409786578268.
# Epoch 34/100
# 41/41 [==============================] - 38s 940ms/step - loss: 0.0054 - acc: 0.3359 - val_loss: 0.0088 - val_acc: 0.3063
# Epoch 35/100
# 41/41 [==============================] - 39s 942ms/step - loss: 0.0054 - acc: 0.3289 - val_loss: 0.0088 - val_acc: 0.2731
# Epoch 36/100
# 41/41 [==============================] - 39s 942ms/step - loss: 0.0053 - acc: 0.3290 - val_loss: 0.0089 - val_acc: 0.3027
#
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 7.4118870543316e-05.
# Epoch 00036: early stopping

# %%
print("final loss",history.history['loss'][-1])
print("final accuracy",history.history['acc'][-1])
print("final validation loss",history.history['val_loss'][-1])
print("final validation accuracy",history.history['val_acc'][-1])
# Out:
# final loss 0.007359813433140516
# final accuracy 0.34967073798179626
# final validation loss 0.009379908442497253
# final validation accuracy 0.3258500099182129

# %%
t = model.predict(noisy_test)

# %%
image = np.random.randint(0, len(noisy_test))

# %%
plt.imshow(noisy_test[image])
plt.show()

# %%
plt.imshow(t[image])
plt.show()

# %%
plt.imshow(clean_test[image])
plt.show()

# %%
from skimage.metrics import peak_signal_noise_ratio

predicted_images = t
psnr_original_mean = 0
psnr_prediction_mean = 0

for gt_img, noisy_img, predicted_img in zip(clean_test, noisy_test, predicted_images):
    psnr_original_mean += peak_signal_noise_ratio(gt_img, noisy_img)
    psnr_prediction_mean += peak_signal_noise_ratio(gt_img, predicted_img)

psnr_original_mean/=clean_test.shape[0]
psnr_prediction_mean/=clean_test.shape[0]
print("Original average gt-noisy PSNR ->", psnr_original_mean)
print("Predicted average gt-predicted PSNR ->", psnr_prediction_mean)
# Out:
# Original average gt-noisy PSNR -> 7.813395419216316
# Predicted average gt-predicted PSNR -> 20.509972044467542

# %%
from skimage.metrics import structural_similarity as ssim

predicted_images = t
ssim_original_mean = 0
ssim_prediction_mean = 0

for gt_img, noisy_img, predicted_img in zip(clean_test, noisy_test, predicted_images):
    ssim_original_mean += ssim(gt_img, noisy_img, multichannel=True, data_range=noisy_img.max() - noisy_img.min())
    ssim_prediction_mean += ssim(gt_img, predicted_img, multichannel=True, data_range=predicted_img.max() - predicted_img.min())

ssim_original_mean/=clean_test.shape[0]
ssim_prediction_mean/=clean_test.shape[0]
print("Original average gt-noisy SSIM ->", ssim_original_mean)
print("Predicted average gt-predicted SSIM ->", ssim_prediction_mean)
# Out:
# Original average gt-noisy SSIM -> 0.19004862808039308
# Predicted average gt-predicted SSIM -> 0.658368338904826
